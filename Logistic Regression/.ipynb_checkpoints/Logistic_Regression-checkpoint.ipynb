# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance)

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance, test_size = 0.2)

# %%
x_test
# Out:
#     age
# 18   19
# 8    62
# 11   28
# 15   55
# 21   26
# 17   58

# %%
model = LogisticRegression()
model.fit(df[['age']], df.bought_insurance)
# Out:
# LogisticRegression()

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0, 1, 0, 1])

# %%
model.predict([[39]])
# Out:
# C:\Users\devan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.coef_
# Out:
# array([[0.13546543]])

# %%
model.intercept_
# Out:
# array([-5.26279121])

# %%
import math

def sigmoid(z):
    return(1 / (1 + math.exp(-z)))
    
def PredictionFunction(x):
    z = -5.26279121 + (0.13546543 * x)
    y = sigmoid(z)
    return y

# %%
PredictionFunction(39)
# Out:
# 0.5050899641631419

# %%
PredictionFunction(38)
# Out:
# 0.4712555121181887

# %%
j = 0
y = []
for i in df.age:
    y.append(PredictionFunction(i))
    j += 1

# %%
plt.scatter(df.age, df.bought_insurance)
plt.plot(df.age, PredictionFunction(df.age))
plt.grid(True)
